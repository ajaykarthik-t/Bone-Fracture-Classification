# %%
import os
from colorama import Fore
from predictions import predict  # Ensure this module and function are available in the environment

# Load images to predict from paths
def load_path(path):
    """
    Load test dataset for prediction.
    """
    dataset = []
    for body in os.listdir(path):
        body_part = body
        path_p = os.path.join(path, body)
        for lab in os.listdir(path_p):
            label = lab
            path_l = os.path.join(path_p, lab)
            for img in os.listdir(path_l):
                img_path = os.path.join(path_l, img)
                dataset.append(
                    {
                        'body_part': body_part,
                        'label': label,
                        'image_path': img_path,
                        'image_name': img
                    }
                )
    return dataset

# Define categories
categories_parts = ["Elbow", "Hand", "Shoulder"]
categories_fracture = ['fractured', 'normal']

# Report predictions with accuracy metrics
def reportPredict(dataset):
    total_count = len(dataset)
    part_count = 0
    status_count = 0

    print(Fore.YELLOW +
          '{0: <28}'.format('Name') +
          '{0: <14}'.format('Part') +
          '{0: <20}'.format('Predicted Part') +
          '{0: <20}'.format('Status') +
          '{0: <20}'.format('Predicted Status'))

    for img in dataset:
        body_part_predict = predict(img['image_path'])
        fracture_predict = predict(img['image_path'], body_part_predict)
        
        if img['body_part'] == body_part_predict:
            part_count += 1
        if img['label'] == fracture_predict:
            status_count += 1
            color = Fore.GREEN
        else:
            color = Fore.RED
        
        print(color +
              '{0: <28}'.format(img['image_name']) +
              '{0: <14}'.format(img['body_part']) +
              '{0: <20}'.format(body_part_predict) +
              '{0: <20}'.format(img['label']) +
              '{0: <20}'.format(fracture_predict))

    # Calculate and print accuracy
    print(Fore.BLUE + f'\nPart Accuracy: {part_count / total_count * 100:.2f}%')
    print(Fore.BLUE + f'Status Accuracy: {status_count / total_count * 100:.2f}%')

# Define path to test directory (adjust as needed)
test_dir = './test'  # Ensure './test' directory exists in the Jupyter Notebook root or adjust the path accordingly

# Run prediction report
reportPredict(load_path(test_dir))
# Out:
# C:\Users\ajayk\anaconda3\envs\py310\lib\site-packages\keras\src\optimizers\base_optimizer.py:32: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Name                        Part          Predicted Part      Status              Predicted Status
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# broken_elbow.jpeg           Elbow         Elbow               fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# elbow2.jpeg                 Elbow         Elbow               fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# elbow2flip.png              Elbow         Elbow               fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# ElbowDan.jpeg               Elbow         Elbow               fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# elbow1.jpeg                 Elbow         Elbow               normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# elbow2.jpg                  Elbow         Elbow               normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# elbow3.jpg                  Elbow         Elbow               normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# broken.jpg                  Hand          Hand                fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# frac.webp                   Hand          Hand                fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# testBlue.jpg                Hand          Hand                fractured           normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# x-ray-1.png                 Hand          Hand                fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# zoom.jfif                   Hand          Hand                fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# download.jfif               Hand          Hand                normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# google1.jfif                Hand          Hand                normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# norm.jpeg                   Hand          Hand                normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# normal.jpeg                 Hand          Hand                normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# normal2.jpg                 Hand          Hand                normal              fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# normleft.jpg                Hand          Hand                normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# normright.jpeg              Hand          Hand                normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# broken_shoulder.jpeg        Shoulder      Shoulder            fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# shoulder1.jpg               Shoulder      Shoulder            fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# shoulder3.jpeg              Shoulder      Shoulder            fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# ShoulderDan.jpg             Shoulder      Shoulder            fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# ShoulderDan2.jpg            Shoulder      Shoulder            fractured           fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# norm.jpg                    Shoulder      Shoulder            normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# norm2.jpg                   Shoulder      Shoulder            normal              fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# norm3.jpeg                  Shoulder      Shoulder            normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# norm4.jpg                   Shoulder      Shoulder            normal              fractured
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# norm5.jpeg                  Shoulder      Shoulder            normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# normalNew.webp              Shoulder      Shoulder            normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# normalNew2.jpg              Shoulder      Shoulder            normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# shoulder1.jpg               Shoulder      Shoulder            normal              normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# shoulder3.jpg               Shoulder      Shoulder            normal              normal
#
# Part Accuracy: 100.00%
# Status Accuracy: 87.88%
